# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Amazon_-_Movies_and_TV_Ratings.csv')

# %%
data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
data.describe().transpose()
# Out:
#           count      mean       std  min   25%  50%  75%  max
# Movie1      1.0  5.000000       NaN  5.0  5.00  5.0  5.0  5.0
# Movie2      1.0  5.000000       NaN  5.0  5.00  5.0  5.0  5.0
# Movie3      1.0  2.000000       NaN  2.0  2.00  2.0  2.0  2.0
# Movie4      2.0  5.000000  0.000000  5.0  5.00  5.0  5.0  5.0
# Movie5     29.0  4.103448  1.496301  1.0  4.00  5.0  5.0  5.0
# ...         ...       ...       ...  ...   ...  ...  ...  ...
# Movie202    6.0  4.333333  1.632993  1.0  5.00  5.0  5.0  5.0
# Movie203    1.0  3.000000       NaN  3.0  3.00  3.0  3.0  3.0
# Movie204    8.0  4.375000  1.407886  1.0  4.75  5.0  5.0  5.0
# Movie205   35.0  4.628571  0.910259  1.0  5.00  5.0  5.0  5.0
# Movie206   13.0  4.923077  0.277350  4.0  5.00  5.0  5.0  5.0
#
# [206 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# user_id        0
# Movie1      4847
# Movie2      4847
# Movie3      4847
# Movie4      4846
#             ...
# Movie202    4842
# Movie203    4847
# Movie204    4840
# Movie205    4813
# Movie206    4835
# Length: 207, dtype: int64

# %%
data.count()
# Out:
# user_id     4848
# Movie1         1
# Movie2         1
# Movie3         1
# Movie4         2
#             ...
# Movie202       6
# Movie203       1
# Movie204       8
# Movie205      35
# Movie206      13
# Length: 207, dtype: int64

# %%
data = data.dropna(how='all')

# %%
views_dict = dict(data.count()[1:])

# %%
for movie,views in views_dict.items():
    if views == max(views_dict.values()):
        print(f'{movie} has maximum views/ratings')
# Out:
# Movie127 has maximum views/ratings

# %%
total_rating = []
for col in data.columns:
    if col != 'user_id':
        total_rating.append(data[col].sum())

# %%
view_count = list(data.count()[1:])

# %%
task_2 = list(np.array(total_rating)/np.array(view_count))

# %%
avg_rating = {}
for i in range(len(list(data.count()[1:].index))):
    avg_rating[list(data.count()[1:].index)[i]] = task_2[i]

# %%
avg_rating
# Out:
# {'Movie1': 5.0,
#  'Movie2': 5.0,
#  'Movie3': 2.0,
#  'Movie4': 5.0,
#  'Movie5': 4.103448275862069,
#  'Movie6': 4.0,
#  'Movie7': 5.0,
#  'Movie8': 5.0,
#  'Movie9': 5.0,
#  'Movie10': 5.0,
#  'Movie11': 5.0,
#  'Movie12': 5.0,
#  'Movie13': 5.0,
#  'Movie14': 4.0,
#  'Movie15': 5.0,
#  'Movie16': 4.51875,
#  'Movie17': 3.0,
#  'Movie18': 5.0,
#  'Movie19': 3.5,
#  'Movie20': 3.0,
#  'Movie21': 5.0,
#  'Movie22': 5.0,
#  'Movie23': 5.0,
#  'Movie24': 4.4,
#  'Movie25': 5.0,
#  'Movie26': 3.0,
#  'Movie27': 5.0,
#  'Movie28': 3.3333333333333335,
#  'Movie29': 4.806584362139918,
#  'Movie30': 4.5,
#  'Movie31': 5.0,
#  'Movie32': 4.5,
#  'Movie33': 5.0,
#  'Movie34': 5.0,
#  'Movie35': 5.0,
#  'Movie36': 5.0,
#  'Movie37': 5.0,
#  'Movie38': 5.0,
#  'Movie39': 5.0,
#  'Movie40': 5.0,
#  'Movie41': 5.0,
#  'Movie42': 5.0,
#  'Movie43': 4.857142857142857,
#  'Movie44': 5.0,
#  'Movie45': 1.0,
#  'Movie46': 5.0,
#  'Movie47': 5.0,
#  'Movie48': 5.0,
#  'Movie49': 5.0,
# ...

# %%
views_dict
# Out:
# {'Movie1': 1,
#  'Movie2': 1,
#  'Movie3': 1,
#  'Movie4': 2,
#  'Movie5': 29,
#  'Movie6': 1,
#  'Movie7': 1,
#  'Movie8': 1,
#  'Movie9': 1,
#  'Movie10': 1,
#  'Movie11': 2,
#  'Movie12': 5,
#  'Movie13': 1,
#  'Movie14': 1,
#  'Movie15': 1,
#  'Movie16': 320,
#  'Movie17': 1,
#  'Movie18': 1,
#  'Movie19': 2,
#  'Movie20': 1,
#  'Movie21': 1,
#  'Movie22': 2,
#  'Movie23': 3,
#  'Movie24': 5,
#  'Movie25': 1,
#  'Movie26': 3,
#  'Movie27': 1,
#  'Movie28': 3,
#  'Movie29': 243,
#  'Movie30': 2,
#  'Movie31': 2,
#  'Movie32': 2,
#  'Movie33': 1,
#  'Movie34': 1,
#  'Movie35': 1,
#  'Movie36': 1,
#  'Movie37': 1,
#  'Movie38': 1,
#  'Movie39': 4,
#  'Movie40': 3,
#  'Movie41': 1,
#  'Movie42': 1,
#  'Movie43': 7,
#  'Movie44': 2,
#  'Movie45': 1,
#  'Movie46': 1,
#  'Movie47': 1,
#  'Movie48': 1,
#  'Movie49': 1,
#  'Movie50': 1,
#  'Movie51': 2,
#  'Movie52': 17,
#  'Movie53': 3,
#  'Movie54': 1,
#  'Movie55': 1,
#  'Movie56': 1,
#  'Movie57': 1,
#  'Movie58': 1,
#  'Movie59': 1,
# ...

# %%
five_rating = {}
for i,j in avg_rating.items():
    if j == 5.0:
         five_rating[i] = avg_rating[i]

# %%
for i,j in five_rating.items():
    five_rating[i] = views_dict[i]

# %%
top_five_rating = {k: v for k, v in sorted(five_rating.items(), key=lambda item: item[1],reverse=True)}

# %%
top_5_movies = []
for i in range(5):
    top_5_movies.append(list(top_five_rating.keys())[i])

# %%
top_5_movies
# Out:
# ['Movie186', 'Movie188', 'Movie191', 'Movie12', 'Movie101']

# %%
least_audience = {k: v for k, v in sorted(five_rating.items(), key=lambda item: item[1])}

# %%
least_audience_list = []
top_5_movies = []
for i in range(5):
    least_audience_list.append(list(least_audience.keys())[i])

# %%
least_audience_list
# Out:
# ['Movie1', 'Movie2', 'Movie7', 'Movie8', 'Movie9']

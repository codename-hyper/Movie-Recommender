# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Amazon_-_Movies_and_TV_Ratings.csv')

# %%
data.head()
# Out:
#           user_id  Movie1  Movie2  Movie3  Movie4  Movie5  Movie6  Movie7  \
# 0  A3R5OBKS7OM2IR     5.0     5.0     NaN     NaN     NaN     NaN     NaN
# 1   AH3QC2PC1VTGP     NaN     NaN     2.0     NaN     NaN     NaN     NaN
# 2  A3LKP6WPMP9UKX     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 3   AVIY68KEPQ5ZD     NaN     NaN     NaN     5.0     NaN     NaN     NaN
# 4  A1CV1WROP5KTTW     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
#    Movie8  Movie9  ...  Movie197  Movie198  Movie199  Movie200  Movie201  \
# 0     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
# 4     NaN     NaN  ...       NaN       NaN       NaN       NaN       NaN
#
#    Movie202  Movie203  Movie204  Movie205  Movie206
# ...

# %%
data.describe().transpose()
# Out:
#           count      mean       std  min   25%  50%  75%  max
# Movie1      1.0  5.000000       NaN  5.0  5.00  5.0  5.0  5.0
# Movie2      1.0  5.000000       NaN  5.0  5.00  5.0  5.0  5.0
# Movie3      1.0  2.000000       NaN  2.0  2.00  2.0  2.0  2.0
# Movie4      2.0  5.000000  0.000000  5.0  5.00  5.0  5.0  5.0
# Movie5     29.0  4.103448  1.496301  1.0  4.00  5.0  5.0  5.0
# ...         ...       ...       ...  ...   ...  ...  ...  ...
# Movie202    6.0  4.333333  1.632993  1.0  5.00  5.0  5.0  5.0
# Movie203    1.0  3.000000       NaN  3.0  3.00  3.0  3.0  3.0
# Movie204    8.0  4.375000  1.407886  1.0  4.75  5.0  5.0  5.0
# Movie205   35.0  4.628571  0.910259  1.0  5.00  5.0  5.0  5.0
# Movie206   13.0  4.923077  0.277350  4.0  5.00  5.0  5.0  5.0
#
# [206 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# user_id        0
# Movie1      4847
# Movie2      4847
# Movie3      4847
# Movie4      4846
#             ...
# Movie202    4842
# Movie203    4847
# Movie204    4840
# Movie205    4813
# Movie206    4835
# Length: 207, dtype: int64

# %%
data.count()
# Out:
# user_id     4848
# Movie1         1
# Movie2         1
# Movie3         1
# Movie4         2
#             ...
# Movie202       6
# Movie203       1
# Movie204       8
# Movie205      35
# Movie206      13
# Length: 207, dtype: int64

# %%
data = data.dropna(how='all')

# %%
views_dict = dict(data.count()[1:])

# %%
for movie,views in views_dict.items():
    if views == max(views_dict.values()):
        print(f'{movie} has maximum views/ratings')
# Out:
# Movie127 has maximum views/ratings
